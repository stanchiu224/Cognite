# %% [markdown]
# ##Read the Cognite Learn content before running code examples.

# %% [markdown]
# ##1. Environment Set Up

# %% [markdown]
# ###Install the Cognite SDK package

# %% [markdown]
# If you recieve the errors:
#
# `ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.`
#
# `ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.`
#
# You can disregard them and do not need to click "Restart Runtime".

# %%
# !pip install cognite-sdk
# !pip install cognite-sdk --upgrade
# !pip install cognite-sdk-core
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cognite-sdk
#   Downloading cognite_sdk-2.56.1-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 13.9 MB/s
# Requirement already satisfied: shapely==1.* in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.8.4)
# Requirement already satisfied: requests-oauthlib==1.* in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.3.1)
# Collecting geopandas==0.10.*
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 56.0 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (2.23.0)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 56.3 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 38.7 MB/s
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib==1.*->cognite-sdk) (3.2.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (1.15.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (2022.6.15)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (2022.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (3.0.4)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas, cognite-sdk
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 cognite-sdk-2.56.1 fiona-1.8.21 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cognite-sdk in /usr/local/lib/python3.7/dist-packages (2.56.1)
# Requirement already satisfied: requests-oauthlib==1.* in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.3.1)
# Requirement already satisfied: shapely==1.* in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.8.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (1.3.5)
# Requirement already satisfied: geopandas==0.10.* in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (0.10.2)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from cognite-sdk) (2.23.0)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas==0.10.*->cognite-sdk) (1.8.21)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas==0.10.*->cognite-sdk) (3.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib==1.*->cognite-sdk) (3.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (2022.6.15)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (22.1.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (57.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (0.7.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas==0.10.*->cognite-sdk) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->cognite-sdk) (2022.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cognite-sdk-core
#   Downloading cognite_sdk_core-2.56.1-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 13.7 MB/s
# Collecting requests-oauthlib==1.3.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from cognite-sdk-core) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib==1.3.0->cognite-sdk-core) (3.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk-core) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk-core) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk-core) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.21.0->cognite-sdk-core) (2022.6.15)
# Installing collected packages: requests-oauthlib, cognite-sdk-core
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.1
#     Uninstalling requests-oauthlib-1.3.1:
#       Successfully uninstalled requests-oauthlib-1.3.1
# Successfully installed cognite-sdk-core-2.56.1 requests-oauthlib-1.3.0

# %% [markdown]
# ###Install the MSAL

# %%
# !pip install msal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting msal
#   Downloading msal-1.19.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.6 MB/s
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.5.0-py3-none-any.whl (20 kB)
# Collecting cryptography<41,>=0.6
#   Downloading cryptography-38.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 32.1 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from msal) (2.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography<41,>=0.6->msal) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography<41,>=0.6->msal) (2.21)
# Collecting types-cryptography>=3.3.21
#   Downloading types_cryptography-3.3.23-py3-none-any.whl (30 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->msal) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->msal) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->msal) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->msal) (2.10)
# Installing collected packages: types-cryptography, PyJWT, cryptography, msal
# Successfully installed PyJWT-2.5.0 cryptography-38.0.1 msal-1.19.0 types-cryptography-3.3.23

# %% [markdown]
# ### Connect to Cognite Data Fusion
# This client object is how all queries will be sent to the Cognite API to retrieve data.
#
# For successfully retrieving the Cognite API, sign in with your user credentials linked to the Azure AD group. For publicdata, your user credentials are the same as you use to sign in to Cognite Hub and Cognite Learn.

# %%
from cognite.client import CogniteClient
from msal import PublicClientApplication
# Contact Project Administrator to get these
TENANT_ID = '48d5043c-cf70-4c49-881c-c638f5796997'
CLIENT_ID = '1b90ede3-271e-401b-81a0-a4d52bea3273'
CDF_CLUSTER = 'api' # api, westeurope-1 etc
COGNITE_PROJECT = 'publicdata'
SCOPES = [f'https://{CDF_CLUSTER}.cognitedata.com/.default']
AUTHORITY_HOST_URI = 'https://login.microsoftonline.com'
AUTHORITY_URI = AUTHORITY_HOST_URI + '/' + TENANT_ID
app = PublicClientApplication(client_id=CLIENT_ID, authority=AUTHORITY_URI)
def authenticate_device_code(app):
  # Firstly, check the cache to see if this end user has signed in before
  accounts = app.get_accounts()
  if accounts:
    creds = app.acquire_token_silent(SCOPES, account=accounts[0])
  else:
    device_flow = app.initiate_device_flow(scopes=SCOPES)
    print(device_flow['message']) # print device code to screen
    creds = app.acquire_token_by_device_flow(flow=device_flow)
  return creds
def get_token():
  return authenticate_device_code(app)['access_token']
client = CogniteClient(
  token_url=f'{AUTHORITY_URI}/v2.0',
  token=get_token,
  token_client_id=CLIENT_ID,
  project=COGNITE_PROJECT,
  base_url=f'https://{CDF_CLUSTER}.cognitedata.com',
  client_name='cognite-python-dev',
)
print(client.iam.token.inspect())
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code C97ST9D7Z to authenticate.
# {
#     "subject": "Eabg9uvifsehlZgdnKWiwO4B3tIFa8ibqW6bTkviTjE",
#     "projects": [
#         {
#             "url_name": "publicdata",
#             "groups": [
#                 4860375157547584,
#                 5824342682088767
#             ]
#         }
#     ],
#     "capabilities": [
#         {
#             "groupsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "assetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "eventsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "rawAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "timeSeriesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "apikeysAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "threedAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "sequencesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "analyticsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "datasetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "filesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "2452112635370053"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "relationshipsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "groupsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "assetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "eventsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "rawAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "timeSeriesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "apikeysAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "threedAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "sequencesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "datasetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "relationshipsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "projectsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "experimentAcl": {
#                 "version": 1,
#                 "actions": [
#                     "USE"
#                 ],
#                 "scope": {
#                     "experimentscope": {
#                         "experiments": [
#                             "identity"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         }
#     ]
# }

# %% [markdown]
# ##2. Retrieving Lists of Assets

# %% [markdown]
# ###List assets
# The `client.assets.list(limit=20)` function retrieves the first `limit` assets, and returns it as an `AssetList`.

# %%
client.assets.list(limit=20)
# Out:
# [<cognite.client.data_classes.assets.Asset object at 0x7f267fc87b50>, <cognite.client.data_classes.assets.Asset object at 0x7f26799a64d0>, <cognite.client.data_classes.assets.Asset object at 0x7f26799a68d0>, <cognite.client.data_classes.assets.Asset object at 0x7f26799a6690>, <cognite.client.data_classes.assets.Asset object at 0x7f26799a6090>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa92d0>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9310>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9350>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9390>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9250>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa93d0>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9410>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9450>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9490>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa94d0>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9510>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9590>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa95d0>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9610>, <cognite.client.data_classes.assets.Asset object at 0x7f2678fa9650>]

# %% [markdown]
# ##Search Assets##
# The `client.assets.search()` function allows you to search by a specific property of the asset, including its name, parent, etc.

# %% [markdown]
# ###Fuzzy Search by name
# The search by name includes results that are similar in name, but not an exact match.

# %%
asset_name = "23-TE-96148"
assets = client.assets.search(name=asset_name)
assets[:5]
# Out:
# [<cognite.client.data_classes.assets.Asset object at 0x7f0112eed310>, <cognite.client.data_classes.assets.Asset object at 0x7f01133abf10>, <cognite.client.data_classes.assets.Asset object at 0x7f01133ab890>, <cognite.client.data_classes.assets.Asset object at 0x7f01133aba50>, <cognite.client.data_classes.assets.Asset object at 0x7f01133ab9d0>]

# %%
type(assets)
# Out:
# cognite.client.data_classes.assets.AssetList

# %% [markdown]
# ###Specific Search
# The `client.assets.retrieve()` interface provides the same information for one specific asset based on the provided ID or external ID.

# %%
asset_id = [a.id for a in assets if a.name==asset_name][0]
client.assets.retrieve(id=asset_id)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>WMT:23-TE-96148</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>23-TE-96148</td>
#     </tr>
#     <tr>
#       <th>parent_id</th>
#       <td>8515799768286580</td>
#     </tr>
#     <tr>
#       <th>parent_external_id</th>
#       <td>WMT:23-TT-96148</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>VRD - PH 1STSTG COMP SEAL GAS HTR</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>5156972057719</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1659105542254</td>
#     </tr>
#     <tr>
#       <th>root_id</th>
#       <td>6687602007296940</td>
#     </tr>
#     <tr>
#       <th>ELC_STATUS_ID</th>
#       <td>1211</td>
#     </tr>
#     <tr>
#       <th>RES_ID</th>
#       <td>532924</td>
#     </tr>
#     <tr>
#       <th>SOURCE_DB</th>
#       <td>workmate</td>
#     </tr>
#     <tr>
#       <th>SOURCE_TABLE</th>
#       <td>wmate_dba.wmt_tag</td>
#     </tr>
#     <tr>
#       <th>WMT_AREA_ID</th>
#       <td>1600</td>
#     </tr>
#     <tr>
#       <th>WMT_CATEGORY_ID</th>
#       <td>1116</td>
#     </tr>
#     <tr>
#       <th>WMT_CONTRACTOR_ID</th>
#       <td>1686</td>
#     </tr>
#     <tr>
#       <th>WMT_FUNC_CODE_ID</th>
#       <td>4564</td>
#     </tr>
#     <tr>
#       <th>WMT_LOCATION_ID</th>
#       <td>1004</td>
#     </tr>
#     <tr>
#       <th>WMT_PO_ID</th>
#       <td>8309</td>
#     </tr>
#     <tr>
#       <th>WMT_SAFETYCRITICALELEMENT_ID</th>
#       <td>1060</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ID</th>
#       <td>4440</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CREATED_DATE</th>
#       <td>2009-06-26 15:36:37</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CRITICALLINE</th>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_DESC</th>
#       <td>VRD - PH 1STSTG COMP SEAL GAS HTR</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_GLOBALID</th>
#       <td>1000000000682252</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_HISTORYREQUIRED</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID</th>
#       <td>346452</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID_ANCESTOR</th>
#       <td>346633</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISACTIVE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISOWNEDBYPROJECT</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_LOOP</th>
#       <td>96148</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_MAINID</th>
#       <td>681760</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_NAME</th>
#       <td>23-TE-96148</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_BY</th>
#       <td>8137</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_DATE</th>
#       <td>2014-07-11 09:25:15</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
[a.id for a in assets if a.name==asset_name]
# Out:
# [5156972057719]

# %% [markdown]
# ##3. Events

# %% [markdown]
# Like we did for assets, we can list events. We will not go more in depth on events here, but you can also filter and search for events.

# %%
client.events.list(limit=7)
# Out:
# [<cognite.client.data_classes.events.Event object at 0x7f01133abc90>, <cognite.client.data_classes.events.Event object at 0x7f010d8844d0>, <cognite.client.data_classes.events.Event object at 0x7f010d884090>, <cognite.client.data_classes.events.Event object at 0x7f010cd85650>, <cognite.client.data_classes.events.Event object at 0x7f010cd857d0>, <cognite.client.data_classes.events.Event object at 0x7f010f9a1950>, <cognite.client.data_classes.events.Event object at 0x7f010f9a1150>]

# %%
client.events.retrieve(external_id="DWH.Primavera_task_2566535")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>DWH.Primavera_task_2566535</td>
#     </tr>
#     <tr>
#       <th>type</th>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>subtype</th>
#       <td>VAL</td>
#     </tr>
#     <tr>
#       <th>asset_ids</th>
#       <td>[4650652196144007]</td>
#     </tr>
#     <tr>
#       <th>source</th>
#       <td>akerbp-cdp</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>14724046590280</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1625756573530</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>1610996539692</td>
#     </tr>
#     <tr>
#       <th>sourceId</th>
#       <td>7112618453384108</td>
#     </tr>
#     <tr>
#       <th>lastUpdatedTime</th>
#       <td>2021-06-10 08:10:09.776</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ##4. Asset Hierarchy and Relationships

# %% [markdown]
# We will generate a list of all children of the main asset of interest. The main asset of interest is listed first, then the children are listed underneath in following rows.

# %%
subtree = client.assets.retrieve_subtree(id=4650652196144007)
subtree[:5]
# Out:
# [<cognite.client.data_classes.assets.Asset object at 0x7f010b94aed0>, <cognite.client.data_classes.assets.Asset object at 0x7f010ba01bd0>, <cognite.client.data_classes.assets.Asset object at 0x7f010b956e10>, <cognite.client.data_classes.assets.Asset object at 0x7f0113857c90>, <cognite.client.data_classes.assets.Asset object at 0x7f010b956ed0>]

# %%
sub2= client.assets.retrieve_subtree(id=5482096081057609)
sub2[:10]
# Out:
# [<cognite.client.data_classes.assets.Asset object at 0x7f0109effe10>, <cognite.client.data_classes.assets.Asset object at 0x7f0109ee3d90>]

# %% [markdown]
# ##5. Collecting Time Series Data

# %% [markdown]
# ###Compile a list of time series objects under the asset
# For each of the assets in the subtree we retrieved, we get the associated time series objects and merge them into a single `TimeSeriesList` object.

# %%
all_timeseries = subtree.time_series()
print(len(all_timeseries),'time series in subtree')
all_timeseries[:5]
# Out:
# 363 time series in subtree
# [<cognite.client.data_classes.time_series.TimeSeries object at 0x7f0109ea4610>, <cognite.client.data_classes.time_series.TimeSeries object at 0x7f0109ea4750>, <cognite.client.data_classes.time_series.TimeSeries object at 0x7f0109ea44d0>, <cognite.client.data_classes.time_series.TimeSeries object at 0x7f0109ea4810>, <cognite.client.data_classes.time_series.TimeSeries object at 0x7f0109ea4650>]

# %% [markdown]
# If you are curious about which asset a time series is attached to, you can retrieve more information of the asset by using the retrieve function. Note that the property is called `asset_id` following typical python style, while `assetId` is used in the underlying API objects and tabular outputs.

# %%
client.assets.retrieve(id=all_timeseries[0].asset_id)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>WMT:23</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>parent_id</th>
#       <td>4650652196144007</td>
#     </tr>
#     <tr>
#       <th>parent_external_id</th>
#       <td>WMT:VAL</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>GAS COMPRESSION AND RE-INJECTION (PH)</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>3111454725058294</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1659105573617</td>
#     </tr>
#     <tr>
#       <th>root_id</th>
#       <td>6687602007296940</td>
#     </tr>
#     <tr>
#       <th>SOURCE_DB</th>
#       <td>workmate</td>
#     </tr>
#     <tr>
#       <th>SOURCE_TABLE</th>
#       <td>wmate_dba.wmt_system</td>
#     </tr>
#     <tr>
#       <th>WMT_LOCATION_ID</th>
#       <td>1004</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ACTIVE</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_CODE</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_DESC</th>
#       <td>GAS COMPRESSION AND RE-INJECTION (PH)</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ID</th>
#       <td>4440</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_NAME</th>
#       <td>GAS COMPRESSION AND RE-INJECTION (PH)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ###View datapoints for specific time series
# The identifier to retrieve Datapoints is the externalId column from the output above.

# %%
client.datapoints.retrieve(external_id="pi:160184", start="8d-ago", end="now")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pi:160184</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2022-09-14 14:34:32.212</th>
#       <td>167881.734375</td>
#     </tr>
#     <tr>
#       <th>2022-09-14 14:34:42.214</th>
#       <td>169716.734375</td>
#     </tr>
#     <tr>
#       <th>2022-09-14 14:34:51.719</th>
#       <td>168788.203125</td>
#     </tr>
#     <tr>
#       <th>2022-09-14 14:35:02.210</th>
#       <td>168704.171875</td>
#     </tr>
#     <tr>
#       <th>2022-09-14 14:35:12.727</th>
#       <td>168004.984375</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2022-09-15 14:29:23.902</th>
#       <td>156347.953125</td>
#     </tr>
#     <tr>
#       <th>2022-09-15 14:29:33.894</th>
#       <td>156824.515625</td>
#     </tr>
#     <tr>
#       <th>2022-09-15 14:29:43.894</th>
#       <td>152163.218750</td>
#     </tr>
#     <tr>
#       <th>2022-09-15 14:29:53.896</th>
#       <td>149577.312500</td>
#     </tr>
#     <tr>
#       <th>2022-09-15 14:30:03.895</th>
#       <td>147899.281250</td>
#     </tr>
#   </tbody>
# </table>
# <p>8565 rows × 1 columns</p>
# </div>

# %% [markdown]
# ##6. Use Cases of CDF Data

# %% [markdown]
# ###Collect datapoints from CDF
# The time series names are defined in the in_ts_exids and out_ts_exid lists below.

# %%
in_ts_exids = ["pi:160182", "pi:160697", "pi:160882"]
out_ts_exid = "pi:160696"

# %% [markdown]
# ###Retrieve Data Points from CDF
# Most object types in the Python SDK have a `to_pandas` method which converts the result to a pandas dataframe. For retrieving aggregates such as the average over each time period, you can use `client.datapoints.retrieve_dataframe` to get a pandas dataframe directly.

# %%
ts_exids = in_ts_exids + [out_ts_exid]
from datetime import datetime, timedelta
train_start_date = datetime(2018, 8, 1)

train_end_date = train_start_date + timedelta(days=30)

datapoints_df = client.datapoints.retrieve_dataframe(external_id=ts_exids,
                                                     aggregates=['average'],
                                                     granularity='1m',
                                                     start=train_start_date,
                                                     end=train_end_date,
                                                     include_aggregate_name=False
                                                     )
datapoints_df.fillna(method="ffill", inplace=True)
datapoints_df.head()
# Out:
#                         pi:160182  pi:160697  pi:160882  pi:160696
# 2018-08-01 00:00:00  91120.918480   3.374376  44.184863   3.251437
# 2018-08-01 00:01:00  86259.975220   3.395966  44.232420   3.274299
# 2018-08-01 00:02:00  90750.665657   3.410101  44.161438   3.287578
# 2018-08-01 00:03:00  91948.525170   3.358822  43.986025   3.237081
# 2018-08-01 00:04:00  93779.111997   3.429458  43.797913   3.306391

# %% [markdown]
# There are also shortcuts for filling the dataframe when using interpolation or count aggregates. Note that without the `include_aggregate_name=False` option, the aggregate name is appended to the external id to form a unique column name.

# %%
datapoints_df_interp = client.datapoints.retrieve_dataframe(external_id=ts_exids[0:2],
                                                           aggregates=['interpolation','count'],
                                                           granularity='1h',
                                                           start=train_start_date,
                                                           end=train_end_date,
                                                           complete="fill"
                                                          )
datapoints_df_interp.head()
# Out:
#                      pi:160182|count  pi:160182|interpolation  \
# 2018-08-01 00:00:00             3522             88106.726602
# 2018-08-01 01:00:00             3517             88266.907953
# 2018-08-01 02:00:00             3535             93328.063281
# 2018-08-01 03:00:00             3521             77838.162189
# 2018-08-01 04:00:00             3516             86494.803008
#
#                      pi:160697|count  pi:160697|interpolation
# 2018-08-01 00:00:00             2853                 3.332684
# 2018-08-01 01:00:00             2852                 3.474739
# 2018-08-01 02:00:00             2810                 3.431560
# 2018-08-01 03:00:00             2836                 3.209425
# 2018-08-01 04:00:00             2847                 3.394040

# %% [markdown]
# ###Visualize the Time Series Data
# The bottom right plot is the output time series, while the other 3 are the inputs used to create an estimate for the output.

# %%
cols = datapoints_df.columns
from matplotlib import pyplot as plt
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,10))
for i, col in enumerate(cols):
    datapoints_df.loc[:, [col]].plot(ax=axes.ravel()[i])

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f00fbd44190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f00fbd82e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f01085c6450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01085fda10>]],
#       dtype=object)

# %% [markdown]
# # **Gatheting Training Data**

# %%
train_x = datapoints_df[in_ts_exids].to_numpy()
train_y = datapoints_df[out_ts_exid].to_numpy()
train_x
# Out:
# array([[9.11209185e+04, 3.37437621e+00, 4.41848626e+01],
#        [8.62599752e+04, 3.39596638e+00, 4.42324197e+01],
#        [9.07506657e+04, 3.41010093e+00, 4.41614384e+01],
#        ...,
#        [1.09582724e+05, 3.19481165e+00, 4.42923385e+01],
#        [1.01517415e+05, 3.19248060e+00, 4.45944329e+01],
#        [9.55404161e+04, 3.29910375e+00, 4.48133932e+01]])

# %%
predict_start_date = train_end_date
# use 1 hour of training data
predict_end_date = train_end_date + timedelta(hours=1)
predict_df = client.datapoints.retrieve_dataframe(
    external_id = ts_exids,
    aggregates=['average'],
    granularity='1m',
    start=predict_start_date,
    end= predict_end_date,
    include_aggregate_name=False)

predict_df.fillna(method='ffill', inplace=True)
predict_df.head()
# Out:
#                          pi:160182  pi:160697  pi:160882  pi:160696
# 2018-08-31 00:00:00   96596.397652   3.390761  44.822433   3.266866
# 2018-08-31 00:01:00   92941.748459   3.382212  44.879119   3.259393
# 2018-08-31 00:02:00  100634.003031   3.477319  45.053927   3.348573
# 2018-08-31 00:03:00  103948.895082   3.434556  45.404786   3.305596
# 2018-08-31 00:04:00  101079.342794   3.348590  45.698323   3.222974

# %%
cols = predict_df.columns

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
for i, col in enumerate(cols):
  predict_df.plot(y=col, ax=axes.ravel()[i])

# %% [markdown]
# # **Create a Basic Linear Regression Model**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
lin_reg = LinearRegression() 
lin_reg.fit(train_x, train_y) 

X = predict_df[in_ts_exids].values 
predict_df["prediction_lin_reg1"] = lin_reg.predict(X) 

# print out mse of the prediction 


mse = mean_squared_error(predict_df[out_ts_exid], predict_df["prediction_lin_reg1"]) 
r2_s = r2_score(predict_df[out_ts_exid], predict_df["prediction_lin_reg1"]) 
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 4))) 
print('The R2 score of our forecasts is {}'.format(round(r2_s, 4))) 

predict_df.plot(y=[out_ts_exid, "prediction_lin_reg1"], figsize=(10, 10))
# Out:
# The Mean Squared Error of our forecasts is 0.0112
# The R2 score of our forecasts is -2.7284

# %%
lin_reg = LinearRegression() 
lin_reg.fit(train_x, train_y) 

X = datapoints_df[in_ts_exids].values 
datapoints_df["prediction_lin_reg1"] = lin_reg.predict(X) 

# print out mse of the prediction 
mse = mean_squared_error(predict_df[out_ts_exid], predict_df["prediction_lin_reg1"]) 
r2_s = r2_score(predict_df[out_ts_exid], predict_df["prediction_lin_reg1"]) 
print('The Mean Squared Error on the training data is {}'.format(round(mse, 4))) 
print('The R2 score of our training data is {}'.format(round(r2_s, 4))) 

datapoints_df.plot(y=[out_ts_exid, "prediction_lin_reg1"], figsize=(10, 10))
# Out:
# The Mean Squared Error on the training data is 0.0112
# The R2 score of our training data is -2.7284

# %% [markdown]
# # **Anomalous Period**

# %%
datapoints_df['state'] = (datapoints_df[out_ts_exid]< 4)*1 
predict_df['state'] = (predict_df[out_ts_exid]< 4)*1

# %%
train_X2 = datapoints_df[in_ts_exids + ['state']].values 

lin_reg = LinearRegression() 
lin_reg.fit(train_X2, train_y) 
X = predict_df[in_ts_exids + ['state']].values 
predict_df["prediction_lin_reg2"] = lin_reg.predict(X) 

# print out mse of the prediction 
mse = mean_squared_error(predict_df[out_ts_exid], predict_df["prediction_lin_reg2"]) 
r2_s = r2_score(predict_df[out_ts_exid], predict_df["prediction_lin_reg2"]) 
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 4))) 
print('The R2 score of our forecasts is {}'.format(round(r2_s, 4))) 

predict_df.plot(y=[out_ts_exid, "prediction_lin_reg2"], figsize=(10, 10))
# Out:
# The Mean Squared Error of our forecasts is 0.0021
# The R2 score of our forecasts is 0.2865

# %%
lin_reg = LinearRegression() 
lin_reg.fit(train_X2, train_y) 

X = datapoints_df[in_ts_exids + ['state']].values 
datapoints_df["prediction_lin_reg2"] = lin_reg.predict(X) 

# print out mse of the prediction 
mse = mean_squared_error(datapoints_df[out_ts_exid], datapoints_df["prediction_lin_reg2"]) 
r2_s = r2_score(datapoints_df[out_ts_exid], datapoints_df["prediction_lin_reg2"]) 
print('The Mean Squared Error on the training data is {}'.format(round(mse, 4))) 
print('The R2 score of our training data is {}'.format(round(r2_s, 4))) 

datapoints_df.plot(y=[out_ts_exid, "prediction_lin_reg2"], figsize=(10, 10))
# Out:
# The Mean Squared Error on the training data is 0.0036
# The R2 score of our training data is 0.9882

# %% [markdown]
# # **Removing Outliers**

# %%
import pandas as pd
quantiles = [0.95, 0.975, 0.98, 0.99] 
quantiles_df = pd.DataFrame( 
     {
          "quantile": quantiles, 
          "value": np.quantile(datapoints_df[out_ts_exid], q=quantiles), 
     } 
) 

quantiles_df
# Out:
#    quantile     value
# 0     0.950  3.372005
# 1     0.975  3.414939
# 2     0.980  3.503425
# 3     0.990  7.387873

# %%
datapoints_df_adj = datapoints_df.loc[datapoints_df[out_ts_exid] < 4, :]

train_X_adj = datapoints_df_adj[in_ts_exids].values 
train_y_adj = datapoints_df_adj[out_ts_exid].values 

lin_reg = LinearRegression() 
lin_reg.fit(train_X_adj, train_y_adj) 

X = predict_df[in_ts_exids].values 
predict_df["prediction_lin_reg3"] = lin_reg.predict(X) 

# print out mse of the prediction 
mse = mean_squared_error(predict_df[out_ts_exid], predict_df["prediction_lin_reg3"]) 
r2_s = r2_score(predict_df[out_ts_exid], predict_df["prediction_lin_reg3"]) 
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 6))) 
print('The R2 score of our forecasts is {}'.format(round(r2_s, 6))) 

predict_df.plot(y=[out_ts_exid, "prediction_lin_reg3"], figsize=(10, 10))
# Out:
# The Mean Squared Error of our forecasts is 2e-06
# The R2 score of our forecasts is 0.999497

# %% [markdown]
# # **Anomaly Detection**

# %% [markdown]
# # **Puzzle**

# %%
client.assets.retrieve(id=928299407571359)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>WMT:23-CB-9129B</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>23-CB-9129B</td>
#     </tr>
#     <tr>
#       <th>parent_id</th>
#       <td>3904753668320840</td>
#     </tr>
#     <tr>
#       <th>parent_external_id</th>
#       <td>WMT:23-1ST STAGE COMP DRY GAS SEAL SYS-PH</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>928299407571359</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1659105551785</td>
#     </tr>
#     <tr>
#       <th>root_id</th>
#       <td>6687602007296940</td>
#     </tr>
#     <tr>
#       <th>ELC_STATUS_ID</th>
#       <td>1211</td>
#     </tr>
#     <tr>
#       <th>SOURCE_DB</th>
#       <td>workmate</td>
#     </tr>
#     <tr>
#       <th>SOURCE_TABLE</th>
#       <td>wmate_dba.wmt_tag</td>
#     </tr>
#     <tr>
#       <th>WMT_AREA_ID</th>
#       <td>1600</td>
#     </tr>
#     <tr>
#       <th>WMT_CATEGORY_ID</th>
#       <td>1120</td>
#     </tr>
#     <tr>
#       <th>WMT_CONTRACTOR_ID</th>
#       <td>1686</td>
#     </tr>
#     <tr>
#       <th>WMT_FUNC_CODE_ID</th>
#       <td>6230</td>
#     </tr>
#     <tr>
#       <th>WMT_LOCATION_ID</th>
#       <td>1004</td>
#     </tr>
#     <tr>
#       <th>WMT_PO_ID</th>
#       <td>8309</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ID</th>
#       <td>4440</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_COMMENT</th>
#       <td>Manufacturer: Indufil / Model: IDGH-1-85-3/4, ...</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CREATED_DATE</th>
#       <td>2009-06-26 15:36:37</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CRITICALLINE</th>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_DESC</th>
#       <td>VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_GLOBALID</th>
#       <td>1000000000707622</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_HISTORYREQUIRED</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID</th>
#       <td>345628</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID_ANCESTOR</th>
#       <td>682540</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISACTIVE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISOWNEDBYPROJECT</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_MAINID</th>
#       <td>681760</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_NAME</th>
#       <td>23-CB-9129B</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_SUFFIX</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_BY</th>
#       <td>1001</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_DATE</th>
#       <td>2015-10-08 15:05:08</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
client.assets.retrieve(id=3257705896277160)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>WMT:23-YE-96117-01</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>23-YE-96117-01</td>
#     </tr>
#     <tr>
#       <th>parent_id</th>
#       <td>3117826349444493</td>
#     </tr>
#     <tr>
#       <th>parent_external_id</th>
#       <td>WMT:23-DB-9101</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>VRD - PH 1STSTGGEAR 1 JOURNBRG DE</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>3257705896277160</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1659105575778</td>
#     </tr>
#     <tr>
#       <th>root_id</th>
#       <td>6687602007296940</td>
#     </tr>
#     <tr>
#       <th>ELC_STATUS_ID</th>
#       <td>1211</td>
#     </tr>
#     <tr>
#       <th>RES_ID</th>
#       <td>300990</td>
#     </tr>
#     <tr>
#       <th>SOURCE_DB</th>
#       <td>workmate</td>
#     </tr>
#     <tr>
#       <th>SOURCE_TABLE</th>
#       <td>wmate_dba.wmt_tag</td>
#     </tr>
#     <tr>
#       <th>WMT_AREA_ID</th>
#       <td>1600</td>
#     </tr>
#     <tr>
#       <th>WMT_CATEGORY_ID</th>
#       <td>1116</td>
#     </tr>
#     <tr>
#       <th>WMT_CONTRACTOR_ID</th>
#       <td>1686</td>
#     </tr>
#     <tr>
#       <th>WMT_FUNC_CODE_ID</th>
#       <td>4621</td>
#     </tr>
#     <tr>
#       <th>WMT_LOCATION_ID</th>
#       <td>1004</td>
#     </tr>
#     <tr>
#       <th>WMT_PO_ID</th>
#       <td>8309</td>
#     </tr>
#     <tr>
#       <th>WMT_SAFETYCRITICALELEMENT_ID</th>
#       <td>1060</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ID</th>
#       <td>4440</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CREATED_DATE</th>
#       <td>2009-06-26 15:36:37</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CRITICALLINE</th>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_DESC</th>
#       <td>VRD - PH 1STSTGGEAR 1 JOURNBRG DE</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_GLOBALID</th>
#       <td>1000000000717815</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_HISTORYREQUIRED</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID</th>
#       <td>346935</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID_ANCESTOR</th>
#       <td>345637</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISACTIVE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISOWNEDBYPROJECT</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_LOOP</th>
#       <td>96117</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_MAINID</th>
#       <td>681760</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_NAME</th>
#       <td>23-YE-96117-01</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_BY</th>
#       <td>8137</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_DATE</th>
#       <td>2014-07-11 09:25:15</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
client.assets.retrieve(id=3810759783087892)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>external_id</th>
#       <td>WMT:60-EN-9010B+29A1</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>60-EN-9010B+29A1</td>
#     </tr>
#     <tr>
#       <th>parent_id</th>
#       <td>3195126756929465</td>
#     </tr>
#     <tr>
#       <th>parent_external_id</th>
#       <td>WMT:23-GK-9107B-M01</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING U...</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>3810759783087892</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1659105581079</td>
#     </tr>
#     <tr>
#       <th>root_id</th>
#       <td>6687602007296940</td>
#     </tr>
#     <tr>
#       <th>ELC_STATUS_ID</th>
#       <td>1211</td>
#     </tr>
#     <tr>
#       <th>SOURCE_DB</th>
#       <td>workmate</td>
#     </tr>
#     <tr>
#       <th>SOURCE_TABLE</th>
#       <td>wmate_dba.wmt_tag</td>
#     </tr>
#     <tr>
#       <th>WMT_AREA_ID</th>
#       <td>1650</td>
#     </tr>
#     <tr>
#       <th>WMT_CATEGORY_ID</th>
#       <td>1115</td>
#     </tr>
#     <tr>
#       <th>WMT_CONTRACTOR_ID</th>
#       <td>1686</td>
#     </tr>
#     <tr>
#       <th>WMT_FUNC_CODE_ID</th>
#       <td>6185</td>
#     </tr>
#     <tr>
#       <th>WMT_LOCATION_ID</th>
#       <td>1004</td>
#     </tr>
#     <tr>
#       <th>WMT_SYSTEM_ID</th>
#       <td>3118</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CREATED_DATE</th>
#       <td>2013-05-28 11:16:05</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_CRITICALLINE</th>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_DESC</th>
#       <td>VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING U...</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_GLOBALID</th>
#       <td>1000000000297589</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_HISTORYREQUIRED</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID</th>
#       <td>701850</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ID_ANCESTOR</th>
#       <td>345930</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISACTIVE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_ISOWNEDBYPROJECT</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_MAINID</th>
#       <td>681760</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_NAME</th>
#       <td>60-EN-9010B+29A1</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_BY</th>
#       <td>1001</td>
#     </tr>
#     <tr>
#       <th>WMT_TAG_UPDATED_DATE</th>
#       <td>2015-10-08 11:47:33</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
client.assets.retrieve_subtree(external_id='WMT:23-PI-96145')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>external_id</th>
#       <th>name</th>
#       <th>parent_id</th>
#       <th>parent_external_id</th>
#       <th>description</th>
#       <th>metadata</th>
#       <th>id</th>
#       <th>created_time</th>
#       <th>last_updated_time</th>
#       <th>root_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>WMT:23-PI-96145</td>
#       <td>23-PI-96145</td>
#       <td>6800693372982143</td>
#       <td>WMT:23-CX-9101</td>
#       <td>VRD - PH 1ST STAGE COMP. PURGE UNIT</td>
#       <td>{'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...</td>
#       <td>1392670717055474</td>
#       <td>0</td>
#       <td>1659105556643</td>
#       <td>6687602007296940</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
client.assets.search(name='23-PI-96145')
# Out:
# [<cognite.client.data_classes.assets.Asset object at 0x7f0106ef9c10>, <cognite.client.data_classes.assets.Asset object at 0x7f0106ef9690>, <cognite.client.data_classes.assets.Asset object at 0x7f0106ef9090>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582a90>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582b90>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582690>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582490>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582dd0>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582090>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582190>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582790>, <cognite.client.data_classes.assets.Asset object at 0x7f01075829d0>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582550>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582d90>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582a10>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582390>, <cognite.client.data_classes.assets.Asset object at 0x7f0107582950>, <cognite.client.data_classes.assets.Asset object at 0x7f0106edd6d0>, <cognite.client.data_classes.assets.Asset object at 0x7f0106eddd50>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c50d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5190>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c51d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5110>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5210>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5250>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5290>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c52d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5310>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5350>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5390>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5410>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5450>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5490>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c54d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5510>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5550>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5590>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c55d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5610>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5650>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5690>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c56d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5710>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5750>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5790>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c57d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5810>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5850>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5890>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c58d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5910>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5950>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5990>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c59d0>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5a10>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5a50>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c5a90>, <cognite.client.data_classes.assets.Asset object at 0x7f01078c53d0 ...
